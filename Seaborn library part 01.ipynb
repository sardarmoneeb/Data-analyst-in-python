# %% [markdown]
# # Seaborn library part 01

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
var = [1,2,3,4,5,6,7,8]
var1 = [8,7,6,5,4,3,2,1]
plt.plot(var,var1)
plt.show()

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import seaborn as sns
import pandas as pd
var = [1,2,3,4,5,6,7,8]
var1 = [8,7,6,5,4,3,2,1]
import pandas as pd
df = pd.DataFrame(({"var":var,"var1":var1}))
sns.lineplot(x = 'var',y = 'var1',data = df)

print(df)
# Out:
#    var  var1
# 0    1     8
# 1    2     7
# 2    3     6
# 3    4     5
# 4    5     4
# 5    6     3
# 6    7     2
# 7    8     1

# %%
a = [10,20,30,40]
b = [40,30,20,10]
import pandas as pd
import seaborn as sns
df = pd.DataFrame({'a':a,'b':b})
sns.lineplot(x = 'a',y = 'b',data = df)
plt.show()

# %% [markdown]
# import  datasets from "Seaborn datasets githum"chrome datasets for penguins

# %%
df = sns.load_dataset("penguins")

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(x = "bill_length_mm",y = "flipper_length_mm",data = df,hue = "sex")
plt.show()

# %%
sns.lineplot(x ="bill_depth_mm",y = "body_mass_g",data = df )
plt.show()

# %%
sns.barplot(x= "bill_length_mm",y = "bill_depth_mm",data = df)
plt.show()

# %%
sns.scatterplot(x= "bill_length_mm",y = "bill_depth_mm",data = df)
plt.show()

# %%
df = sns.load_dataset("penguins").head(20)

# %%
df
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.lineplot(x = "bill_length_mm",y = "bill_depth_mm",data = df,style = "sex",markers = ["o",">"])
plt.grid()
plt.title("This is a line grapgh of penguins")
plt.show()

# %%
sns.barplot(x = "bill_length_mm",y = "bill_depth_mm",data = df)
plt.show()
