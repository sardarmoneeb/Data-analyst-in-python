# %% [markdown]
# # pandas library

# %%
import pandas as pd

# Create a DataFrame
data = {
    'Name': ['John', 'Alice', 'Bob', 'Eve','moneeb','saran','abdul','wahab','bilal'],
    'Age': [28, 25, 32, 30,40,67,12,76,78],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston','kotli','Rawalakot','Muzaffarabad','Pindi','Pounch']
}

df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#      Name  Age          City
# 0    John   28      New York
# 1   Alice   25   Los Angeles
# 2     Bob   32       Chicago
# 3     Eve   30       Houston
# 4  moneeb   40         kotli
# 5   saran   67     Rawalakot
# 6   abdul   12  Muzaffarabad
# 7   wahab   76         Pindi
# 8   bilal   78        Pounch

# %%
df
# Out:
#      Name  Age          City
# 0    John   28      New York
# 1   Alice   25   Los Angeles
# 2     Bob   32       Chicago
# 3     Eve   30       Houston
# 4  moneeb   40         kotli
# 5   saran   67     Rawalakot
# 6   abdul   12  Muzaffarabad
# 7   wahab   76         Pindi
# 8   bilal   78        Pounch

# %%
df.head()
# Out:
#      Name  Age         City
# 0    John   28     New York
# 1   Alice   25  Los Angeles
# 2     Bob   32      Chicago
# 3     Eve   30      Houston
# 4  moneeb   40        kotli

# %%
df.tail()
# Out:
#      Name  Age          City
# 4  moneeb   40         kotli
# 5   saran   67     Rawalakot
# 6   abdul   12  Muzaffarabad
# 7   wahab   76         Pindi
# 8   bilal   78        Pounch

# %%
df.describe()
# Out:
#              Age
# count   9.000000
# mean   43.111111
# std    24.235534
# min    12.000000
# 25%    28.000000
# 50%    32.000000
# 75%    67.000000
# max    78.000000

# %%
df.dtypes
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
df[['Name']][4:9]
# Out:
#      Name
# 4  moneeb
# 5   saran
# 6   abdul
# 7   wahab
# 8   bilal

# %%
df.dtypes == 'object'
# Out:
# Name     True
# Age     False
# City     True
# dtype: bool

# %%
import pandas as pd

# Sample data (just a snippet)
data = {
    'Name': ['John', 'Alice', 'Bob', 'Eve', 'Michael', 'Emily', 'James', 'Emma', 'William', 'Olivia'],
    'Age': [28, 25, 32, 30, 35, 29, 27, 31, 33, 26],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'San Francisco', 'Boston', 'Seattle', 'Dallas', 'Austin', 'Denver'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],
    'Education': ['Masters', 'Bachelors', 'PhD', 'Bachelors', 'Masters', 'PhD', 'Bachelors', 'Masters', 'Bachelors', 'Masters'],
    'Salary': [70000, 60000, 90000, 65000, 80000, 95000, 60000, 85000, 70000, 75000],
    'Department': ['Sales', 'Marketing', 'Engineering', 'HR', 'Engineering', 'Sales', 'Marketing', 'Engineering', 'HR', 'Marketing']
}

# Create DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           City  Gender  Education  Salary   Department
# 0     John   28       New York    Male    Masters   70000        Sales
# 1    Alice   25    Los Angeles  Female  Bachelors   60000    Marketing
# 2      Bob   32        Chicago    Male        PhD   90000  Engineering
# 3      Eve   30        Houston  Female  Bachelors   65000           HR
# 4  Michael   35  San Francisco    Male    Masters   80000  Engineering
# 5    Emily   29         Boston  Female        PhD   95000        Sales
# 6    James   27        Seattle    Male  Bachelors   60000    Marketing
# 7     Emma   31         Dallas  Female    Masters   85000  Engineering
# 8  William   33         Austin    Male  Bachelors   70000           HR
# 9   Olivia   26         Denver  Female    Masters   75000    Marketing

# %%
df
# Out:
#       Name  Age           City  Gender  Education  Salary   Department
# 0     John   28       New York    Male    Masters   70000        Sales
# 1    Alice   25    Los Angeles  Female  Bachelors   60000    Marketing
# 2      Bob   32        Chicago    Male        PhD   90000  Engineering
# 3      Eve   30        Houston  Female  Bachelors   65000           HR
# 4  Michael   35  San Francisco    Male    Masters   80000  Engineering
# 5    Emily   29         Boston  Female        PhD   95000        Sales
# 6    James   27        Seattle    Male  Bachelors   60000    Marketing
# 7     Emma   31         Dallas  Female    Masters   85000  Engineering
# 8  William   33         Austin    Male  Bachelors   70000           HR
# 9   Olivia   26         Denver  Female    Masters   75000    Marketing

# %%
df.head(10)
# Out:
#       Name  Age           City  Gender  Education  Salary   Department
# 0     John   28       New York    Male    Masters   70000        Sales
# 1    Alice   25    Los Angeles  Female  Bachelors   60000    Marketing
# 2      Bob   32        Chicago    Male        PhD   90000  Engineering
# 3      Eve   30        Houston  Female  Bachelors   65000           HR
# 4  Michael   35  San Francisco    Male    Masters   80000  Engineering
# 5    Emily   29         Boston  Female        PhD   95000        Sales
# 6    James   27        Seattle    Male  Bachelors   60000    Marketing
# 7     Emma   31         Dallas  Female    Masters   85000  Engineering
# 8  William   33         Austin    Male  Bachelors   70000           HR
# 9   Olivia   26         Denver  Female    Masters   75000    Marketing

# %%
df.tail(5)
# Out:
#       Name  Age     City  Gender  Education  Salary   Department
# 5    Emily   29   Boston  Female        PhD   95000        Sales
# 6    James   27  Seattle    Male  Bachelors   60000    Marketing
# 7     Emma   31   Dallas  Female    Masters   85000  Engineering
# 8  William   33   Austin    Male  Bachelors   70000           HR
# 9   Olivia   26   Denver  Female    Masters   75000    Marketing

# %%
df.describe()
# Out:
#              Age        Salary
# count  10.000000     10.000000
# mean   29.600000  75000.000000
# std     3.204164  12247.448714
# min    25.000000  60000.000000
# 25%    27.250000  66250.000000
# 50%    29.500000  72500.000000
# 75%    31.750000  83750.000000
# max    35.000000  95000.000000

# %%
df.dtypes
# Out:
# Name          object
# Age            int64
# City          object
# Gender        object
# Education     object
# Salary         int64
# Department    object
# dtype: object

# %%
df.dtypes == 'int64'
# Out:
# Name          False
# Age            True
# City          False
# Gender        False
# Education     False
# Salary         True
# Department    False
# dtype: bool

# %%
df[df.dtypes[df.dtypes == 'int64'].index][0:5]
# Out:
#    Age  Salary
# 0   28   70000
# 1   25   60000
# 2   32   90000
# 3   30   65000
# 4   35   80000

# %%
df['Address'] = "Ajk"

# %%
df
# Out:
#       Name  Age           City  Gender  Education  Salary   Department Address
# 0     John   28       New York    Male    Masters   70000        Sales     Ajk
# 1    Alice   25    Los Angeles  Female  Bachelors   60000    Marketing     Ajk
# 2      Bob   32        Chicago    Male        PhD   90000  Engineering     Ajk
# 3      Eve   30        Houston  Female  Bachelors   65000           HR     Ajk
# 4  Michael   35  San Francisco    Male    Masters   80000  Engineering     Ajk
# 5    Emily   29         Boston  Female        PhD   95000        Sales     Ajk
# 6    James   27        Seattle    Male  Bachelors   60000    Marketing     Ajk
# 7     Emma   31         Dallas  Female    Masters   85000  Engineering     Ajk
# 8  William   33         Austin    Male  Bachelors   70000           HR     Ajk
# 9   Olivia   26         Denver  Female    Masters   75000    Marketing     Ajk

# %%
df.insert(loc=4, column='Join year',value=2020)

# %%
df
# Out:
#       Name  Age           City  Gender  Join year  Education  Salary  \
# 0     John   28       New York    Male       2020    Masters   70000
# 1    Alice   25    Los Angeles  Female       2020  Bachelors   60000
# 2      Bob   32        Chicago    Male       2020        PhD   90000
# 3      Eve   30        Houston  Female       2020  Bachelors   65000
# 4  Michael   35  San Francisco    Male       2020    Masters   80000
# 5    Emily   29         Boston  Female       2020        PhD   95000
# 6    James   27        Seattle    Male       2020  Bachelors   60000
# 7     Emma   31         Dallas  Female       2020    Masters   85000
# 8  William   33         Austin    Male       2020  Bachelors   70000
# 9   Olivia   26         Denver  Female       2020    Masters   75000
#
#     Department Address
# 0        Sales     Ajk
# 1    Marketing     Ajk
# 2  Engineering     Ajk
# 3           HR     Ajk
# 4  Engineering     Ajk
# 5        Sales     Ajk
# 6    Marketing     Ajk
# ...

# %%
df[['Name','Department','Address']][0:5]
# Out:
#       Name   Department Address
# 0     John        Sales     Ajk
# 1    Alice    Marketing     Ajk
# 2      Bob  Engineering     Ajk
# 3      Eve           HR     Ajk
# 4  Michael  Engineering     Ajk
